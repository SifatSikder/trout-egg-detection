# %%
# %%capture
# !pip install ultralytics

# %%
# %%capture
from google.colab import drive
drive.mount('/content/drive')

# %%
from ultralytics import YOLO
model = YOLO('yolo11n.pt')
model.train(data='/content/drive/MyDrive/Computer Vision/Object(EGG) Detection Using YOLO/data/config.yaml', epochs=200)
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# 100%|██████████| 5.35M/5.35M [00:00<00:00, 282MB/s]
# Ultralytics 8.3.96 🚀 Python-3.11.11 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
results = model.predict(source='/content/drive/MyDrive/Computer Vision/Object(EGG) Detection Using YOLO/data/test/trout_egg.jpg', save=True)
# Out:
# image 1/1 /content/drive/MyDrive/Computer Vision/Object(EGG) Detection Using YOLO/data/test/trout_egg.jpg: 640x640 2 eggs, 9.8ms
# Speed: 3.0ms preprocess, 9.8ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/train2

# %%
import shutil
src = "/content/runs/detect/train"
dst = "/content/drive/MyDrive/Computer Vision/Object(EGG) Detection Using YOLO/model"
shutil.copytree(src, dst)
